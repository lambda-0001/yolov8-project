# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r"C:\Users\31440\Desktop\yolov8\runs\detect\train10\weights\best.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model([r"C:\Users\31440\Desktop\yolov8\test1_images\1.jpg", r"C:\Users\31440\Desktop\yolov8\test1_images\2.jpg"])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    print(boxes)
    masks = result.masks  # Masks object for segmentation masks outputs
    #print(masks)
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# 0: 96x128 (no detections), 366.6ms
# 1: 96x128 (no detections), 366.6ms
# Speed: 3.4ms preprocess, 366.6ms inference, 2.6ms postprocess per image at shape (1, 3, 96, 128)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (720, 1280)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (720, 1280)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))

# %%
"""
#图片预测结果的基础信息，包含缩放后的尺寸、预测出的类别个数和名称、单张图片推理时间
0: 96x128 (no detections), 349.1ms
1: 96x128 (no detections), 349.1ms

#预测完整过程时间：推理前处理（尺寸缩放）、中期算法推理（YOLOV8 inference）、结果后处理（NMS）
Speed: 16.5ms preprocess, 349.1ms inference, 0.3ms postprocess per image at shape (1, 3, 96, 128)
ultralytics.engine.results.Boxes object with attributes:


#classes:输出预测类别索引(与标注规则保持一致)
cls: tensor([])
#confidence:置信度。表示有多少概率属于某个类别
conf: tensor([])

#data每一行：表示每个预测目标的信息
#data每一列：表示的信息是固定的，x1,y1,x2,y2,confidence,classes
data: tensor([], size=(0, 6))

#是否目标跟踪
id: None
is_track: False

#原图尺寸
orig_shape: (720, 1280)
#是上面data数组的尺寸
shape: torch.Size([0, 6])
xywh: tensor([], size=(0, 4))
xywhn: tensor([], size=(0, 4))
xyxy: tensor([], size=(0, 4))
xyxyn: tensor([], size=(0, 4))
ultralytics.engine.results.Boxes object with attributes:

cls: tensor([])
conf: tensor([])
data: tensor([], size=(0, 6))
id: None
is_track: False
orig_shape: (720, 1280)
shape: torch.Size([0, 6])
xywh: tensor([], size=(0, 4))
xywhn: tensor([], size=(0, 4))
xyxy: tensor([], size=(0, 4))
xyxyn: tensor([], size=(0, 4))


"""
