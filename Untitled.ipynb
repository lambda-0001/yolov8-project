# %%
import cv2
import albumentations as A
import random
import matplotlib.pyplot as plt

image = cv2.imread(r'C:\Users\31440\Desktop\yolov8\datasets\images\train\1.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)


#xmin,ymin,width,height
bboxes = [[11,1,883,681]]

category = [0]        

transform = A.Compose(
    [A.RandomSizedBBoxSafeCrop(width=100,height=82,erosion_rate=0.2)],
    bbox_params=A.BboxParams(format='coco',label_fields=['category_ids'])
)

xmin,ymin,width, height = bbox
x1, y1 = int(xmin), int(ymin)
x2, y2 = int(xmin + width), int(ymin + height)
text=str(transformed_categories[0])
cv2.rectangle(image, (x1,y1),(x2,y2),(0,0,255),1)
cv2.putText(image, str(transformed_categories[0]), (xmin,ymin+20),cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255))
plt.imshow(image)

# %%
for obj transformed.iter("object"):
    cls = obj.find("name").text
    xmlbox = obj.find("bndbox")
    print(cls)
    xmin = int(xmlbox.find("xmin").text)
    ymin = int(xmlbox.find("ymin").text)
    xmax = int(xmlbox.find("xmax").text)
    ymax = int(xmlbox.find("ymax").text)
    cv2.rectangle(image, (xmin,ymin),(xmax,ymax),(0,0,255),1)
    cv2.putText(image, 'text', (xmin,ymin+10),cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255))
    img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,8))
plt.imshow(img_rgb)
plt.show()
# Out:
#   Cell In[3], line 1
#     for obj transformed.iter("object"):
#             ^
# SyntaxError: invalid syntax
